# %%
import json
import scanpy as sc

# %%
special_tokens = ['<PAD>', '<CLS>', '<MASK>']

# %% [markdown]
# ## GENES VOCAB GENERATOR

# %%
#adata = sc.datasets.pbmc3k()
adata = sc.read_10x_mtx(
    "data/filtered_feature_bc_matrix",
    var_names="gene_symbols",
    cache=True,
)
with open("data/gene-id-vocab.json", "w") as f:
    gene_ids_ = dict( enumerate(list(adata.var['gene_ids']) + special_tokens ))
    gene_ids = dict([ i[::-1] for i in gene_ids_.items() ])
    json.dump(gene_ids, f)

# %%
#special_tokens + list(adata.var['gene_ids'])

# %% [markdown]
# ## CONDITIONS VOCAB GENERATOR

# %%
"""
with open("condition-vocab.json", "w") as f:
    conditions = ["sick", "healthy"]
    conditions_ = enumerate(conditions)
   
    conditions = dict([ i[::-1] for i in conditions_ ])

    json.dump(conditions, f)
"""

# %%
import pandas as pd

# %%
df = pd.read_csv("raw.tsv", delimiter="\t")

# %%
df.shape
# Out:
# (1212, 19939)

# %%
df.sample(3)
# Out:
#                                    file_id    A1BG    A1CF       A2M    A2ML1  \
# 1096  4ed31cce-6d4f-4c79-a4e4-80eaedd1c4d2  0.0656  0.0000  225.0623   0.1392
# 477   435f3fbf-5c8f-4800-bff4-3b4d5f9daf2e  0.0368  0.0102   58.5183  12.6526
# 685   6c3f2469-50ea-48a7-bb17-043e74e54535  0.2073  0.0152  474.6430   0.3748
#
#       A3GALT2   A4GALT   A4GNT     AAAS     AACS  ...   ZWILCH     ZWINT  \
# 1096   0.0513  37.6934  0.0295  30.1601   5.2371  ...   5.5017   40.1027
# 477    0.0000  28.7150  0.0000  39.7189  11.6815  ...  21.2314  116.2115
# 685    0.1430  11.9661  0.1919  31.5471  12.0521  ...  13.0381   27.9213
#
#         ZXDA     ZXDB     ZXDC   ZYG11A   ZYG11B       ZYX    ZZEF1     ZZZ3
# 1096  0.7139   2.2863   6.1240   2.2229   3.3290  100.0682   3.9899   3.4808
# 477   3.0869   9.2403  14.3271  11.0073  10.2212  150.7550   6.4115  12.4512
# 685   7.1493  17.2009  19.2158   4.7165  21.5478  251.5114  21.3837  27.4086
#
# [3 rows x 19939 columns]
